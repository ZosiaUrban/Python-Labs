# %%
import numpy as np 
import matplotlib.pyplot as plt

# create an arrya of x values

x=np.linspace(0,10,100)
y=np.sin(x)

plt.plot(x,y)
plt.xlabel('x')
plt.ylabel('y')
plt.ylabel('sin(x)')
plt.title('sin(x)')
plt.show()
